# %%
### Germanium

import numpy as np
import matplotlib.pyplot as plt

RINDEX = np.arange(1,6,0.5)
LY_30nm = [0.163, 0.168, 0.180, 0.188, 0.193, 0.192, 0.187, 0.174, 0.166, 0.154] #keV/MeV
LY_30nm_err = [0.001, 0.001, 0.001, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001]
LY_60nm = [0.164, 0.182, 0.211, 0.220, 0.205, 0.185, 0.170, 0.165, 0.160, 0.155] #keV/MeV
LY_60nm_err = [0.001, 0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001]
LY_90nm = [0.162, 0.199, 0.213, 0.189, 0.171, 0.169, 0.172, 0.171, 0.169, 0.161] #keV/MeV
LY_90nm_err = [0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.002, 0.001, 0.001, 0.001]
LY_120nm = [0.163, 0.201, 0.182, 0.169, 0.181, 0.192, 0.182, 0.168, 0.161, 0.155] #keV/MeV
LY_120nm_err = [0.001, 0.002, 0.001, 0.002, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_150nm = [0.163, 0.185, 0.169, 0.190, 0.203, 0.182, 0.170, 0.169, 0.167, 0.157] #keV/MeV
LY_150nm_err = [0.001, 0.001, 0.001, 0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.002]

plt.errorbar(RINDEX, LY_30nm, yerr=LY_30nm_err, label='30nm', lw=0.5, marker='s')
plt.errorbar(RINDEX, LY_60nm, yerr=LY_60nm_err, label='60nm', lw=0.5, marker='o')
plt.errorbar(RINDEX, LY_90nm, yerr=LY_90nm_err, label='90nm', lw=0.5, marker='v')
plt.errorbar(RINDEX, LY_120nm, yerr=LY_120nm_err, label='120nm', lw=0.5, marker='x')
plt.hlines(0.164, 0, 6, color='black', ls="--", label='no coating')
plt.hlines(0.234, 0, 6, color='black', ls="-.", label='ideal LD')
plt.vlines(1, 0.1, 0.3, color='black', lw=0.8)
plt.vlines(5.5, 0.1, 0.3, color='black', lw=0.8)
plt.text(0.9, 0.185, r'$n_0$', rotation=90, rotation_mode='anchor')
plt.text(5.4, 0.185, r'$n_2$', rotation=90, rotation_mode='anchor')
plt.legend(loc='center right', bbox_to_anchor=(0.96, 0.75))
plt.xlim(0,5.7)
plt.ylim(0.135,0.239)
plt.xlabel('coating RINDEX')
plt.ylabel('S1 LY [keV/MeV]')
plt.title('SCOPSim | ground LMO | Ge LD')
plt.savefig('Ge_coating_RINDEX.png', dpi=400)

# %%
### Silicium

import numpy as np
import matplotlib.pyplot as plt

RINDEX = np.arange(1,6,0.5)
LY_30nm = [0.177, 0.181, 0.189, 0.195, 0.197, 0.191, 0.180, 0.164, 0.149, 0.137] #keV/MeV
LY_30nm_err = [0.002, 0.001, 0.002, 0.002, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_60nm = [0.176, 0.195, 0.218, 0.219, 0.200, 0.184, 0.176, 0.174, 0.172, 0.163] #keV/MeV
LY_60nm_err = [0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_90nm = [0.177, 0.210, 0.215, 0.196, 0.181, 0.183, 0.180, 0.168, 0.156, 0.152] #keV/MeV
LY_90nm_err = [0.002, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.002, 0.001, 0.001]
LY_120nm = [0.176, 0.211, 0.191, 0.183, 0.192, 0.188, 0.177, 0.170, 0.166, 0.154] #keV/MeV
LY_120nm_err = [0.002, 0.002, 0.002, 0.001, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001]

plt.errorbar(RINDEX, LY_30nm, yerr=LY_30nm_err, label='30nm', lw=0.5, marker='s')
plt.errorbar(RINDEX, LY_60nm, yerr=LY_60nm_err, label='60nm', lw=0.5, marker='o')
plt.errorbar(RINDEX, LY_90nm, yerr=LY_90nm_err, label='90nm', lw=0.5, marker='v')
plt.errorbar(RINDEX, LY_120nm, yerr=LY_120nm_err, label='120nm', lw=0.5, marker='x')
plt.hlines(0.177, 0, 6, color='black', ls="--", label='no coating')
plt.hlines(0.234, 0, 6, color='black', ls="-.", label='ideal LD')
plt.vlines(1, 0.1, 0.3, color='black', lw=0.8)
plt.vlines(4, 0.1, 0.3, color='black', lw=0.8)
plt.text(0.9, 0.205, r'$n_0$', rotation=90, rotation_mode='anchor')
plt.text(3.9, 0.205, r'$n_2$', rotation=90, rotation_mode='anchor')
plt.legend(loc='center right', bbox_to_anchor=(0.99, 0.71))
plt.xlim(0,5.7)
plt.ylim(0.135,0.239)
plt.xlabel('coating RINDEX')
plt.ylabel('S1 LY [keV/MeV]')
plt.title('SCOPSim | ground LMO | Si LD')
plt.savefig('Si_coating_RINDEX.png', dpi=400)

# %%
# Thickness

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(4.5,3.5), constrained_layout=True)

coat_thickness = np.arange(45, 86, 1)
LY_SiO = [0.450332, 0.451818, 0.454731, 0.456045, 0.459115, 0.461128, 0.461724, 0.46279, 0.465638, 0.466212, 0.466754, 0.467882, 0.468702, 0.469271, 0.470043, 0.468619, 0.468421, 0.467167, 0.467479, 0.464474, 0.465033, 0.464187, 0.462873, 0.460679, 0.458346, 0.457086, 0.455614, 0.452749, 0.449877, 0.44739, 0.444258, 0.441627, 0.439438, 0.43669, 0.434932, 0.432861, 0.429133, 0.426317, 0.42335, 0.421874, 0.417568]
LY_SiO_err = [0.000628191, 0.000603251, 0.000601279, 0.000615944, 0.000608178, 0.000598602, 0.000617837, 0.000607651, 0.000613022, 0.000595014, 0.000613647, 0.00061061, 0.000621993, 0.000633675, 0.000615907, 0.000612414, 0.0006226, 0.000635997, 0.000622925, 0.000594616, 0.000592816, 0.000613703, 0.000603749, 0.000613289, 0.000612103, 0.000594467, 0.000614323, 0.000587376, 0.000591082, 0.000590771, 0.000582644, 0.000572436, 0.000590713, 0.000572936, 0.000571901, 0.000583197, 0.000557251, 0.000569827, 0.000560943, 0.000565189, 0.000544242]
#LY_SiN = [0.444146, 0.446291, 0.446515, 0.449227, 0.452055, 0.453295, 0.455941, 0.454974, 0.456727, 0.459295, 0.461176, 0.462317, 0.463496, 0.467277, 0.467677, 0.467942, 0.468962, 0.470096, 0.470894, 0.471701, 0.471398, 0.471345, 0.472576, 0.472337, 0.472025, 0.472621, 0.47289, 0.471853, 0.471922, 0.471296, 0.470184, 0.470828, 0.467737, 0.470015, 0.467664, 0.466078, 0.46554, 0.464935, 0.464503, 0.461371, 0.459942]
#LY_SiN_err = [0.000583224, 0.000600372, 0.000624151, 0.000593193, 0.000627031, 0.000628574, 0.000614191, 0.000589098, 0.000605028, 0.000621148, 0.000602231, 0.000621466, 0.000607364, 0.000603557, 0.000608555, 0.000632777, 0.00063422, 0.000605944, 0.000621154, 0.000640671, 0.00063234, 0.000632071, 0.00062901, 0.000614445, 0.000603804, 0.000616823, 0.000633291, 0.000626301, 0.000632296, 0.000595755, 0.000628756, 0.000644986, 0.000591193, 0.000665418, 0.000611775, 0.000614751, 0.000631607, 0.000606764, 0.000686294, 0.00058894, 0.000588581]
LY_SiN = [0.438488, 0.441636, 0.442627, 0.444296, 0.446302, 0.449561, 0.450748, 0.451549, 0.454708, 0.455665, 0.457832, 0.459368, 0.459712, 0.463468, 0.46256, 0.464439, 0.465643, 0.466722, 0.468551, 0.469668, 0.469703, 0.467873, 0.470466, 0.471128, 0.470894, 0.471075, 0.472363, 0.471339, 0.473689, 0.471398, 0.471853, 0.471665, 0.471405, 0.471007, 0.470181, 0.470066, 0.469542, 0.468465, 0.466647, 0.466012, 0.465306]
LY_SiN_err = [0.000583181, 0.000588063, 0.000596199, 0.000603241, 0.000615839, 0.000627603, 0.000603375, 0.000607786, 0.000589771, 0.000616317, 0.000616568, 0.000609003, 0.000594174, 0.00063968, 0.000604813, 0.000625731, 0.000614833, 0.000615247, 0.000607092, 0.000635182, 0.000613403, 0.000617069, 0.000626075, 0.000629679, 0.000611186, 0.00061811, 0.000626414, 0.000621111, 0.000626348, 0.000627748, 0.000618867, 0.000597366, 0.000604989, 0.000617053, 0.0006097, 0.000630421, 0.000618549, 0.000630368, 0.000610149, 0.000607804, 0.000618867]


plt.errorbar(coat_thickness, LY_SiO, yerr=LY_SiO_err, label='SCOPSim Ge with SiO coating', lw=1, marker='o', markersize=5, color='green')
plt.errorbar(coat_thickness, LY_SiN, yerr=LY_SiN_err, label='SCOPSim Si with SiN coating', lw=1, marker='v', markersize=5, color='magenta')

plt.vlines(60, 0.4, 0.5, color='green', ls='--', label='SiO in CUPID experiments', lw=1.5)
plt.vlines(70, 0.4, 0.5, color='magenta', ls='--', label='SiN in CUPID experiments', lw=1.5)

plt.xlabel('coating thickness [nm]')
plt.ylabel(r'$LY_{det}$ [keV/MeV]')
plt.legend()
plt.ylim(0.41, 0.48)
plt.savefig('thickness.png', dpi=300)
