# %%
### Germanium

import numpy as np
import matplotlib.pyplot as plt

RINDEX = np.arange(1,6,0.5)
LY_30nm = [0.163, 0.168, 0.180, 0.188, 0.193, 0.192, 0.187, 0.174, 0.166, 0.154] #keV/MeV
LY_30nm_err = [0.001, 0.001, 0.001, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001]
LY_60nm = [0.164, 0.182, 0.211, 0.220, 0.205, 0.185, 0.170, 0.165, 0.160, 0.155] #keV/MeV
LY_60nm_err = [0.001, 0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001, 0.001]
LY_90nm = [0.162, 0.199, 0.213, 0.189, 0.171, 0.169, 0.172, 0.171, 0.169, 0.161] #keV/MeV
LY_90nm_err = [0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.002, 0.001, 0.001, 0.001]
LY_120nm = [0.163, 0.201, 0.182, 0.169, 0.181, 0.192, 0.182, 0.168, 0.161, 0.155] #keV/MeV
LY_120nm_err = [0.001, 0.002, 0.001, 0.002, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_150nm = [0.163, 0.185, 0.169, 0.190, 0.203, 0.182, 0.170, 0.169, 0.167, 0.157] #keV/MeV
LY_150nm_err = [0.001, 0.001, 0.001, 0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.002]

plt.errorbar(RINDEX, LY_30nm, yerr=LY_30nm_err, label='30nm', lw=0.5, marker='s')
plt.errorbar(RINDEX, LY_60nm, yerr=LY_60nm_err, label='60nm', lw=0.5, marker='o')
plt.errorbar(RINDEX, LY_90nm, yerr=LY_90nm_err, label='90nm', lw=0.5, marker='v')
plt.errorbar(RINDEX, LY_120nm, yerr=LY_120nm_err, label='120nm', lw=0.5, marker='x')
plt.hlines(0.164, 0, 6, color='black', ls="--", label='no coating')
plt.hlines(0.234, 0, 6, color='black', ls="-.", label='ideal LD')
plt.vlines(1, 0.1, 0.3, color='black', lw=0.8)
plt.vlines(5.5, 0.1, 0.3, color='black', lw=0.8)
plt.text(0.9, 0.185, r'$n_0$', rotation=90, rotation_mode='anchor')
plt.text(5.4, 0.185, r'$n_2$', rotation=90, rotation_mode='anchor')
plt.legend(loc='center right', bbox_to_anchor=(0.96, 0.75))
plt.xlim(0,5.7)
plt.ylim(0.135,0.239)
plt.xlabel('coating RINDEX')
plt.ylabel('S1 LY [keV/MeV]')
plt.title('SCOPSim | ground LMO | Ge LD')
plt.savefig('Ge_coating_RINDEX.png', dpi=400)

# %%
### Silicium

import numpy as np
import matplotlib.pyplot as plt

RINDEX = np.arange(1,6,0.5)
LY_30nm = [0.177, 0.181, 0.189, 0.195, 0.197, 0.191, 0.180, 0.164, 0.149, 0.137] #keV/MeV
LY_30nm_err = [0.002, 0.001, 0.002, 0.002, 0.001, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_60nm = [0.176, 0.195, 0.218, 0.219, 0.200, 0.184, 0.176, 0.174, 0.172, 0.163] #keV/MeV
LY_60nm_err = [0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001]
LY_90nm = [0.177, 0.210, 0.215, 0.196, 0.181, 0.183, 0.180, 0.168, 0.156, 0.152] #keV/MeV
LY_90nm_err = [0.002, 0.002, 0.002, 0.002, 0.001, 0.001, 0.001, 0.002, 0.001, 0.001]
LY_120nm = [0.176, 0.211, 0.191, 0.183, 0.192, 0.188, 0.177, 0.170, 0.166, 0.154] #keV/MeV
LY_120nm_err = [0.002, 0.002, 0.002, 0.001, 0.002, 0.002, 0.001, 0.001, 0.001, 0.001]

plt.errorbar(RINDEX, LY_30nm, yerr=LY_30nm_err, label='30nm', lw=0.5, marker='s')
plt.errorbar(RINDEX, LY_60nm, yerr=LY_60nm_err, label='60nm', lw=0.5, marker='o')
plt.errorbar(RINDEX, LY_90nm, yerr=LY_90nm_err, label='90nm', lw=0.5, marker='v')
plt.errorbar(RINDEX, LY_120nm, yerr=LY_120nm_err, label='120nm', lw=0.5, marker='x')
plt.hlines(0.177, 0, 6, color='black', ls="--", label='no coating')
plt.hlines(0.234, 0, 6, color='black', ls="-.", label='ideal LD')
plt.vlines(1, 0.1, 0.3, color='black', lw=0.8)
plt.vlines(4, 0.1, 0.3, color='black', lw=0.8)
plt.text(0.9, 0.205, r'$n_0$', rotation=90, rotation_mode='anchor')
plt.text(3.9, 0.205, r'$n_2$', rotation=90, rotation_mode='anchor')
plt.legend(loc='center right', bbox_to_anchor=(0.99, 0.71))
plt.xlim(0,5.7)
plt.ylim(0.135,0.239)
plt.xlabel('coating RINDEX')
plt.ylabel('S1 LY [keV/MeV]')
plt.title('SCOPSim | ground LMO | Si LD')
plt.savefig('Si_coating_RINDEX.png', dpi=400)
